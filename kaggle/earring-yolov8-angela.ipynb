# %% [markdown]
# # Earrings Object Detection

# %%
# !pip install ultralytics==8.0.146
# Out:
# Requirement already satisfied: ultralytics==8.0.146 in /opt/conda/lib/python3.10/site-packages (8.0.146)
# Requirement already satisfied: matplotlib>=3.2.2 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.0.146) (3.7.3)
# Requirement already satisfied: numpy>=1.22.2 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.0.146) (1.24.3)
# Requirement already satisfied: opencv-python>=4.6.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.0.146) (4.8.1.78)
# Requirement already satisfied: pillow>=7.1.2 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.0.146) (10.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.0.146) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.0.146) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.0.146) (1.11.3)
# Requirement already satisfied: torch>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.0.146) (2.0.0)
# Requirement already satisfied: torchvision>=0.8.1 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.0.146) (0.15.1)
# Requirement already satisfied: tqdm>=4.64.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.0.146) (4.66.1)
# Requirement already satisfied: pandas>=1.1.4 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.0.146) (2.0.3)
# Requirement already satisfied: seaborn>=0.11.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.0.146) (0.12.2)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.0.146) (5.9.3)
# Requirement already satisfied: py-cpuinfo in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.0.146) (9.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.2.2->ultralytics==8.0.146) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.2.2->ultralytics==8.0.146) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.2.2->ultralytics==8.0.146) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.2.2->ultralytics==8.0.146) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.2.2->ultralytics==8.0.146) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.2.2->ultralytics==8.0.146) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.2.2->ultralytics==8.0.146) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics==8.0.146) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics==8.0.146) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics==8.0.146) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics==8.0.146) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics==8.0.146) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics==8.0.146) (2023.7.22)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics==8.0.146) (3.12.2)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics==8.0.146) (4.5.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics==8.0.146) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics==8.0.146) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics==8.0.146) (3.1.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->ultralytics==8.0.146) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.7.0->ultralytics==8.0.146) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.7.0->ultralytics==8.0.146) (1.3.0)

# %%
import ultralytics  ##就是yoloV8
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.146 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5173.5/8062.4 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %%
## 檢查是否有所需的檔案
# !ls /kaggle/input/earring-opencv
# Out:
# earring_opencv

# %%
## 檢查是否有所需的檔案
# !ls /kaggle/input/earring-opencv/earring_opencv
# Out:
# images	labels

# %% [markdown]
# # Train Model

# %%
# https://docs.ultralytics.com/usage/cli/
# https://github.com/roboflow/notebooks/blob/main/notebooks/train-yolov8-object-detection-on-custom-dataset.ipynb

# data: yaml file to define path to data, classes' names
# model: yolov8x.pt yolov8l.pt yolov8m.pt yolov8s.pt yolov8n.pt
# a full list of train arguments: https://docs.ultralytics.com/usage/cfg/

## 模型訓練 ## yaml檔裡的路徑要記得改!!!!
# !yolo task=detect mode=train model=yolov8m.pt \
data= "/kaggle/input/earring-kaggle2-yaml/earring_kaggle2.yaml" \
optimizer='auto' \
batch=48 \
epochs=25 \
patience=5 \
imgsz=480 \
plots=True \
flipud=0.3 \
fliplr=0.3 \
mixup=0.5 \
copy_paste=0.5 \
project='out'
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# New https://pypi.org/project/ultralytics/8.0.215 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.146 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15110MiB)
# engine/trainer: task=detect, mode=train, model=yolov8m.pt, data=/kaggle/input/earring-kaggle2-yaml/earring_kaggle2.yaml, epochs=25, patience=5, batch=48, imgsz=480, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.3, fliplr=0.3, mosaic=1, mixup=0.5, copy_paste=0.5, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train2
# Overriding model.yaml nc=80 with nc=49
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
#   8                  -1  2   3985920  ultralytics.nn.modules.block.C2f             [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.block.SPPF            [576, 576, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  2   1993728  ultralytics.nn.modules.block.C2f             [960, 384, 2]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  2    517632  ultralytics.nn.modules.block.C2f             [576, 192, 2]
#  16                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  2   1846272  ultralytics.nn.modules.block.C2f             [576, 384, 2]
#  19                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  2   4207104  ultralytics.nn.modules.block.C2f             [960, 576, 2]
#  22        [15, 18, 21]  1   3804067  ultralytics.nn.modules.head.Detect           [49, [192, 384, 576]]
# Model summary: 295 layers, 25884691 parameters, 25884675 gradients
#
# Transferred 469/475 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train2', view at http://localhost:6006/
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████████████████████████████████| 6.23M/6.23M [00:00<00:00, 72.3MB/s]
# AMP: checks passed ✅
# train: Scanning /kaggle/input/earring-opencv/earring_opencv/labels/train... 8262
# train: WARNING ⚠️ Cache directory /kaggle/input/earring-opencv/earring_opencv/labels is not writeable, cache not saved.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /kaggle/input/earring-opencv/earring_opencv/labels/valid... 2112 i
# val: WARNING ⚠️ Cache directory /kaggle/input/earring-opencv/earring_opencv/labels is not writeable, cache not saved.
# Plotting labels to runs/detect/train2/labels.jpg...
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# optimizer: AdamW(lr=0.000189, momentum=0.9) with parameter groups 77 weight(decay=0.0), 84 weight(decay=0.000375), 83 bias(decay=0.0)
# Image sizes 480 train, 480 val
# Using 2 dataloader workers
# Logging results to runs/detect/train2
# Starting training for 25 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/25      11.7G      1.185      2.776      1.382          2        480: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2388       3416      0.855      0.848      0.901        0.7
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/25        12G      1.025      1.289      1.246          2        480: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2388       3416      0.874      0.888      0.944      0.749
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/25        12G      1.016      1.128      1.248          5        480: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2388       3416      0.883      0.897      0.941      0.733
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/25      11.9G      1.009      1.045      1.247         11        480: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2388       3416      0.895      0.922      0.951      0.756
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/25        12G     0.9852     0.9658      1.235         12        480: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2388       3416      0.912      0.931      0.959      0.771
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/25      11.9G     0.9587     0.9005      1.221          2        480: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2388       3416      0.929       0.95      0.972      0.788
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/25        12G     0.9444     0.8416      1.212          2        480: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2388       3416      0.921      0.961      0.969      0.793
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/25        12G     0.9182     0.7935      1.193          1        480: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2388       3416      0.952      0.972       0.98      0.809
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/25      11.9G     0.9053     0.7418      1.184          6        480: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2388       3416      0.944       0.97      0.976      0.806
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/25      11.9G     0.8887     0.7083      1.176          3        480: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2388       3416      0.936      0.974      0.981      0.814
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/25        12G     0.8781     0.6946      1.164          5        480: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2388       3416      0.965      0.972       0.98      0.816
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/25      11.9G     0.8733     0.6598      1.156          7        480: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2388       3416      0.978      0.971      0.985      0.828
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/25      11.9G     0.8455     0.6322      1.145         11        480: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2388       3416      0.946      0.979      0.982      0.829
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/25      11.9G     0.8483     0.6254      1.141          3        480: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2388       3416      0.969      0.976      0.983      0.832
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/25      11.9G     0.8273     0.5931      1.128          6        480: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2388       3416       0.97      0.978      0.984       0.84
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/25      11.9G     0.7171     0.3737      1.062          1        480: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2388       3416      0.972      0.974      0.984      0.835
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/25      11.9G     0.7016     0.3495      1.052          1        480: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2388       3416      0.973      0.983      0.986      0.843
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/25      11.9G     0.6876     0.3403      1.042          1        480: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2388       3416      0.981      0.982      0.987      0.846
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/25      11.9G     0.6808      0.319      1.036          1        480: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2388       3416      0.979      0.982      0.988       0.85
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/25      11.9G     0.6675     0.3084      1.025          6        480: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2388       3416      0.982      0.982      0.988      0.854
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/25      11.9G     0.6496     0.2918      1.013          0        480: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2388       3416      0.987      0.985      0.988      0.857
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/25      11.9G     0.6397     0.3067       1.01          1        480: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2388       3416      0.989      0.987      0.988      0.862
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/25      11.9G     0.6309     0.2726     0.9956          0        480: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2388       3416      0.989      0.988      0.988      0.862
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/25      11.9G     0.6221     0.2746     0.9909          1        480: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2388       3416      0.988      0.986      0.988      0.866
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/25      11.9G     0.6141     0.2659     0.9938          1        480: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2388       3416      0.988      0.988      0.988      0.866
#
# 25 epochs completed in 3.238 hours.
# Optimizer stripped from runs/detect/train2/weights/last.pt, 52.1MB
# Optimizer stripped from runs/detect/train2/weights/best.pt, 52.1MB
#
# Validating runs/detect/train2/weights/best.pt...
# Ultralytics YOLOv8.0.146 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15110MiB)
# Model summary (fused): 218 layers, 25868131 parameters, 0 gradients
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2388       3416      0.988      0.988      0.988      0.866
#       01_black_dot_pin       2388        195       0.98      0.981      0.987      0.729
#         02_sliver_hook       2388         81      0.999          1      0.995      0.751
#      03_green_ring_pin       2388         62          1      0.988      0.995      0.821
#         04_yellow_ball       2388         46      0.995          1      0.995      0.706
#          05_green_ring       2388         47      0.993          1      0.995      0.931
#          06_white_ring       2388         54      0.996          1      0.995      0.853
#     07_white_thin_ring       2388         66      0.982          1      0.992      0.854
#            08_slippers       2388         29      0.989          1      0.995      0.927
#                09_hand       2388         49      0.975          1       0.99      0.835
#                10_coke       2388         48          1          1      0.995      0.912
#         11_green_plate       2388         50      0.994          1      0.995      0.965
#        12_yellow_plate       2388         44      0.994          1      0.995      0.903
#                13_soju       2388         30      0.991          1      0.995      0.895
#   14_yellow_square_pin       2388         35      0.992          1      0.995      0.914
#            15_ear_clip       2388         85      0.997          1      0.995      0.955
#              16_ribbon       2388         50      0.995          1      0.995      0.913
#              17_flower       2388         57      0.996          1      0.995        0.9
#                18_bear       2388         52      0.995          1      0.995      0.941
#      19_yellow_dot_pin       2388         43      0.994          1      0.995       0.89
#                20_oval       2388         53      0.994          1      0.995      0.968
#        21_blue_polygon       2388         48      0.993          1      0.995      0.938
#               22_corgi       2388         61      0.994          1      0.995      0.963
#        23_metal_square       2388         51      0.969          1      0.995      0.951
#             24_big_eye       2388         44      0.994          1      0.995      0.845
#           25_small_eye       2388         44      0.997          1      0.995      0.854
#               26_pearl       2388         54      0.989      0.963      0.988      0.738
#       27_gemstone_ring       2388         59      0.994          1      0.995      0.953
#    28_four_leaf_clover       2388         78      0.985          1      0.994      0.833
#       29_hollow_flower       2388         72      0.965          1      0.977      0.836
#     30_mother_of_pearl       2388         74       0.96      0.973       0.99      0.889
#            31_red_bead       2388         93      0.997          1      0.995      0.775
#      32_water_droplets       2388         26      0.966          1      0.995      0.936
#         33_silver_rose       2388         49      0.995          1      0.995       0.89
#       34_big_polka_dot       2388         49      0.968       0.98      0.976      0.866
#    35_large_black_ring       2388        110      0.991      0.985      0.995      0.981
#       36_white_dot_pin       2388         42       0.97      0.976      0.977      0.759
#                37_girl       2388         20          1      0.695      0.737      0.621
#     38_small_polka_dot       2388         20      0.984          1      0.995       0.92
#   39_medium_black_ring       2388         70      0.976          1      0.993       0.94
#    40_small_black_ring       2388         22      0.953      0.912      0.988        0.9
#       41_black_polygon       2388         81      0.996          1      0.995      0.892
#       42_white_polygon       2388        107      0.997          1      0.995      0.917
#            43_dinosaur       2388        175      0.992          1      0.995      0.927
#         44_golden_hook       2388        130          1      0.986      0.995      0.853
#            45_fox_face       2388        129      0.998          1      0.995      0.936
#            46_red_cone       2388        244      0.979      0.963      0.989      0.661
#              47_tassel       2388        126      0.983      0.992      0.995      0.789
#          48_golden_pin       2388        102      0.979          1      0.993      0.706
#         49_yellow_ring       2388         60      0.996          1      0.995      0.821
# Speed: 0.2ms preprocess, 5.7ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to runs/detect/train2

# %% [markdown]
# # Evaluate Model

# %%
#7.列出模型訓練輸出之路徑資料
# !ls /kaggle/working/runs
# Out:
# detect

# %%
#8.壓縮資料準備產生連結供下載
# !zip -r file.zip /kaggle/working/runs
# Out:
#   adding: kaggle/working/runs/ (stored 0%)
#   adding: kaggle/working/runs/detect/ (stored 0%)
#   adding: kaggle/working/runs/detect/train2/ (stored 0%)
#   adding: kaggle/working/runs/detect/train2/R_curve.png (deflated 11%)
#   adding: kaggle/working/runs/detect/train2/train_batch0.jpg (deflated 4%)
#   adding: kaggle/working/runs/detect/train2/events.out.tfevents.1700617464.96243ece8d6c.199.0 (deflated 72%)
#   adding: kaggle/working/runs/detect/train2/weights/ (stored 0%)
#   adding: kaggle/working/runs/detect/train2/weights/best.pt (deflated 8%)
#   adding: kaggle/working/runs/detect/train2/weights/last.pt (deflated 8%)
#   adding: kaggle/working/runs/detect/train2/train_batch2.jpg (deflated 4%)
#   adding: kaggle/working/runs/detect/train2/val_batch1_labels.jpg (deflated 13%)
#   adding: kaggle/working/runs/detect/train2/P_curve.png (deflated 16%)
#   adding: kaggle/working/runs/detect/train2/labels.jpg (deflated 30%)
#   adding: kaggle/working/runs/detect/train2/val_batch0_labels.jpg (deflated 13%)
#   adding: kaggle/working/runs/detect/train2/val_batch0_pred.jpg (deflated 13%)
#   adding: kaggle/working/runs/detect/train2/train_batch2940.jpg (deflated 15%)
#   adding: kaggle/working/runs/detect/train2/train_batch2941.jpg (deflated 8%)
#   adding: kaggle/working/runs/detect/train2/confusion_matrix_normalized.png (deflated 15%)
#   adding: kaggle/working/runs/detect/train2/PR_curve.png (deflated 20%)
#   adding: kaggle/working/runs/detect/train2/val_batch1_pred.jpg (deflated 12%)
#   adding: kaggle/working/runs/detect/train2/val_batch2_pred.jpg (deflated 13%)
#   adding: kaggle/working/runs/detect/train2/confusion_matrix.png (deflated 15%)
#   adding: kaggle/working/runs/detect/train2/train_batch1.jpg (deflated 3%)
#   adding: kaggle/working/runs/detect/train2/args.yaml (deflated 51%)
#   adding: kaggle/working/runs/detect/train2/results.csv (deflated 84%)
#   adding: kaggle/working/runs/detect/train2/results.png (deflated 8%)
#   adding: kaggle/working/runs/detect/train2/F1_curve.png (deflated 11%)
#   adding: kaggle/working/runs/detect/train2/labels_correlogram.jpg (deflated 35%)
#   adding: kaggle/working/runs/detect/train2/train_batch2942.jpg (deflated 10%)
#   adding: kaggle/working/runs/detect/train2/val_batch2_labels.jpg (deflated 14%)
#   adding: kaggle/working/runs/detect/train/ (stored 0%)
#   adding: kaggle/working/runs/detect/train/weights/ (stored 0%)
#   adding: kaggle/working/runs/detect/train/events.out.tfevents.1700617193.96243ece8d6c.98.0 (deflated 9%)
#   adding: kaggle/working/runs/detect/train/args.yaml (deflated 51%)

# %% [markdown]
# ##**Inference on test data**

# %%
#9.產生下載連結
from IPython.display import FileLink
FileLink(r'file.zip')
# Out:
# /kaggle/working/file.zip
