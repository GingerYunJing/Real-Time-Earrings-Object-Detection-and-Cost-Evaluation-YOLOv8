# %%
# before you run the kaggle notebook
# plz add data to input: 1.best-weight, 2.earring-kaggle2-yaml, 3.earring_opencv
# To validate and predict, Yolo needs best weight you've trained, validation data set and yaml file with all configuration it needs
# !pip install ultralytics==8.0.146

# %%
from ultralytics import YOLO
w = "/kaggle/input/best-weight/best.pt"

# Current working directory
# !pwd

# # Change working directory
# %cd /kaggle

# # Copy directory from a to b
# !cp "/kaggle/input/best-weight/best.pt" '/kaggle'

# # list files under working directory
# !ls


# Load a model
model = YOLO(w)  # load a custom model


# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category

# %%
# after training and validation

model.metrics # find validation results using this
